# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os,sys
import cv2

import tensorflow as tf
from tensorflow import keras
from keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import pickle as p
from tensorflow.keras import layers, models
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix 
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array



initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=100)

def Upload_Dataset(Dataset_Path):
   
    Path_train_Dataset = Dataset_Path+"/train"
    Path_test_Dataset = Dataset_Path+"/test"
    Path_val_Dataset = Dataset_Path+"/val"
   
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = [], [], []
    Output_train, Output_test, Output_val = [], [], []

    for j in os.listdir(Path_train_Dataset):

        if j != ".DS_Store":
            #print(j)
            for k in os.listdir(Path_train_Dataset+"/"+j):
                img=cv2.imread(Path_train_Dataset+"/"+j+"/"+k)
                Input_train_Dataset.append(cv2.resize(img, (224, 224)))
                if(j == 'brain'):
                    print('0 Entered ',j)
                    Output_train.append(int(0))
                elif(j == 'ewer'):
                    print('1 Entered ',j)
                    Output_train.append(int(1))
                elif(j == 'helicopter'):
                    print('2 Entered ',j)
                    Output_train.append(int(2))
                elif(j == 'scorpion'):
                    print('3 Entered ',j)
                    Output_train.append(int(3))
                else:
                    print('4 Entered ',j)
                    Output_train.append(int(4))

            for k in os.listdir(Path_test_Dataset+"/"+j):
                img=cv2.imread(Path_test_Dataset+"/"+j+"/"+k)
                Input_test_Dataset.append(cv2.resize(img, (224, 224)))
                if(j == 'brain'):
                    Output_test.append(int(0))
                elif(j == 'ewer'):
                    Output_test.append(int(1))
                elif(j == 'helicopter'):
                    Output_test.append(int(2))
                elif(j == 'scorpion'):
                    Output_test.append(int(3))
                else:
                    Output_test.append(int(4))

            for k in os.listdir(Path_val_Dataset+"/"+j):
                img=cv2.imread(Path_val_Dataset+"/"+j+"/"+k)
                Input_val_Dataset.append(cv2.resize(img, (224, 224)))
                if(j == 'brain'):
                    Output_val.append(int(0))
                elif(j == 'ewer'):
                    Output_val.append(int(1))
                elif(j == 'helicopter'):
                    Output_val.append(int(2))
                elif(j == 'scorpion'):
                    Output_val.append(int(3))
                else:
                    Output_val.append(int(4))
       
    #print(Output_train)            
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = np.array(Input_train_Dataset), np.array(Input_test_Dataset), np.array(Input_val_Dataset)
    #Output_train, Output_test, Output_val = np.array(list(map(int, Output_train))), np.array(list(map(int, Output_test))), np.array(list(map(int, Output_val)))
    Output_train, Output_test, Output_val = np.array(Output_train), np.array(Output_test), np.array(Output_val)
    #print(Output_train)
    return Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val
#providing path of  Caltech-101 dataset
Dataset_Path = "/content/drive/MyDrive/DLA5/Group_1"

#calling Upload_Dataset function
trainInp, testInp,valInp, trainOut, testOut, valOut= Upload_Dataset(Dataset_Path)

#Architecture1
model = models.Sequential()
#First Layer
model.add(layers.Conv2D(8, (11, 11), strides=4,activation='relu',name='conv1', padding='valid',input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((3, 3,), strides=2,name='MaxPool1', padding='valid'))

#Second Layer
model.add(layers.Conv2D(16, (5, 5), strides=1,activation='relu',name='conv2',padding='valid', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((3, 3,), strides=2, name='MaxPool2',padding='valid'))
#3 Layer
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu', name='hiddenLayer'))
#4th layer
model.add(layers.Dense(5, activation='softmax', name='outputLayer'))

model.summary()

optimizer=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-6,name='Adam')

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=3,verbose=1)

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x = trainInp, y = trainOut, batch_size = 32, epochs = 10000, verbose = "auto", callbacks=[es], validation_data=(valInp,  valOut), validation_batch_size=1)

model.save('/content/drive/MyDrive/DLA5/a1.h5')
f=open('/content/drive/MyDrive/DLA4/Histae32.pckl','wb')
p.dump(history.history,f)
f.close()

'''Dataset used for prediction and evaluation  data'''
trainEncode=model.predict(trainInp)
valEncode=model.predict(valInp)
testEncode=model.predict(testInp)

#a,b-part

print('\nEvaluation of model on train data:')
trainAcc=model.evaluate(x=trainInp,y=trainOut,batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(trainAcc)

print('\nEvaluation of model on validation data:')
valAcc=model.evaluate(x=valInp, y=valOut, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(valAcc)

print('\nEvaluation of model on test data:')
testAcc=model.evaluate(x=testInp, y=testOut, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(testAcc)

print('\nPredictions for test data:')
testProb=model.predict(testInp, batch_size=1, verbose="auto", callbacks=None)
pred=np.argmax(testProb,axis=1)
print(pred)

'''3-3'''
#confusionMatrix=confusion_matrix(Output_test, pred)
confusionMatrix=confusion_matrix(testOut,pred)
#confusionMatrix=tf.math.confusion_matrix(Output_test, pred5)
print(confusionMatrix)
# Out:
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 54, 54, 8)         2912
#
#  MaxPool1 (MaxPooling2D)     (None, 26, 26, 8)         0
#
#  conv2 (Conv2D)              (None, 22, 22, 16)        3216
#
#  MaxPool2 (MaxPooling2D)     (None, 10, 10, 16)        0
#
#  flatten (Flatten)           (None, 1600)              0
#
#  hiddenLayer (Dense)         (None, 128)               204928
#
#  outputLayer (Dense)         (None, 5)                 645
#
# =================================================================
# Total params: 211,701
# Trainable params: 211,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# 8/8 [==============================] - 4s 321ms/step - loss: 65.7154 - accuracy: 0.2360 - val_loss: 11.8258 - val_accuracy: 0.2400
# Epoch 2/10000
# 8/8 [==============================] - 2s 295ms/step - loss: 8.1816 - accuracy: 0.2000 - val_loss: 3.5411 - val_accuracy: 0.2000
# Epoch 3/10000
# 8/8 [==============================] - 2s 274ms/step - loss: 1.9980 - accuracy: 0.2880 - val_loss: 1.9601 - val_accuracy: 0.3600
# Epoch 4/10000
# 8/8 [==============================] - 3s 464ms/step - loss: 1.4000 - accuracy: 0.3760 - val_loss: 1.5803 - val_accuracy: 0.3600
# Epoch 5/10000
# 8/8 [==============================] - 3s 354ms/step - loss: 1.2660 - accuracy: 0.4480 - val_loss: 1.4644 - val_accuracy: 0.4200
# Epoch 6/10000
# 8/8 [==============================] - 2s 287ms/step - loss: 1.1619 - accuracy: 0.5320 - val_loss: 1.4208 - val_accuracy: 0.4400
# Epoch 7/10000
# 8/8 [==============================] - 2s 293ms/step - loss: 1.0628 - accuracy: 0.5920 - val_loss: 1.5041 - val_accuracy: 0.4200
# Epoch 8/10000
# 8/8 [==============================] - 2s 273ms/step - loss: 0.9511 - accuracy: 0.5840 - val_loss: 1.6181 - val_accuracy: 0.5000
# Epoch 9/10000
# 8/8 [==============================] - 3s 345ms/step - loss: 0.8462 - accuracy: 0.6840 - val_loss: 1.4916 - val_accuracy: 0.5200
# Epoch 10/10000
# 8/8 [==============================] - 4s 488ms/step - loss: 0.7434 - accuracy: 0.7080 - val_loss: 1.6914 - val_accuracy: 0.4000
# Epoch 11/10000
# 8/8 [==============================] - 2s 293ms/step - loss: 0.5459 - accuracy: 0.7920 - val_loss: 1.9801 - val_accuracy: 0.4800
# Epoch 12/10000
# 8/8 [==============================] - 2s 271ms/step - loss: 0.4787 - accuracy: 0.8000 - val_loss: 1.7762 - val_accuracy: 0.4200
# Epoch 13/10000
# 8/8 [==============================] - 2s 290ms/step - loss: 0.3818 - accuracy: 0.8800 - val_loss: 1.9203 - val_accuracy: 0.5200
# Epoch 14/10000
# 8/8 [==============================] - 2s 272ms/step - loss: 0.3242 - accuracy: 0.9120 - val_loss: 1.7698 - val_accuracy: 0.4800
# Epoch 15/10000
# 8/8 [==============================] - 4s 491ms/step - loss: 0.3809 - accuracy: 0.8800 - val_loss: 1.8267 - val_accuracy: 0.5200
# Epoch 16/10000
# 8/8 [==============================] - 3s 332ms/step - loss: 0.1778 - accuracy: 0.9400 - val_loss: 2.6246 - val_accuracy: 0.4200
# Epoch 17/10000
# 8/8 [==============================] - 2s 288ms/step - loss: 0.1515 - accuracy: 0.9520 - val_loss: 2.1529 - val_accuracy: 0.4400
# Epoch 18/10000
# 8/8 [==============================] - 2s 288ms/step - loss: 0.1206 - accuracy: 0.9760 - val_loss: 2.7832 - val_accuracy: 0.4200
# Epoch 19/10000
# 8/8 [==============================] - 2s 292ms/step - loss: 0.0757 - accuracy: 0.9840 - val_loss: 3.1127 - val_accuracy: 0.4200
# Epoch 20/10000
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0554 - accuracy: 0.9960 - val_loss: 2.6140 - val_accuracy: 0.4400
# Epoch 21/10000
# 8/8 [==============================] - 3s 428ms/step - loss: 0.0334 - accuracy: 0.9960 - val_loss: 3.0216 - val_accuracy: 0.4200
# Epoch 22/10000
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 2.9940 - val_accuracy: 0.4600
# Epoch 23/10000
# 8/8 [==============================] - 2s 276ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 2.8804 - val_accuracy: 0.4600
# Epoch 24/10000
# 8/8 [==============================] - 2s 288ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 2.9802 - val_accuracy: 0.4600
# Epoch 25/10000
# 8/8 [==============================] - 2s 277ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 3.3713 - val_accuracy: 0.4200
# Epoch 26/10000
# 8/8 [==============================] - 4s 562ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 3.5208 - val_accuracy: 0.4600
# Epoch 27/10000
# 8/8 [==============================] - 2s 287ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 3.4203 - val_accuracy: 0.4600
# Epoch 28/10000
# 8/8 [==============================] - 2s 267ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 3.5170 - val_accuracy: 0.4600
# Epoch 29/10000
# 8/8 [==============================] - 2s 293ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.5244 - val_accuracy: 0.4600
# Epoch 30/10000
# 8/8 [==============================] - 2s 292ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.5676 - val_accuracy: 0.4600
# Epoch 31/10000
# 8/8 [==============================] - 3s 460ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.6978 - val_accuracy: 0.4600
# Epoch 32/10000
# 8/8 [==============================] - 3s 343ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.7258 - val_accuracy: 0.4600
# Epoch 33/10000
# 8/8 [==============================] - 2s 292ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.7175 - val_accuracy: 0.4600
# Epoch 34/10000
# 8/8 [==============================] - 2s 278ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.7693 - val_accuracy: 0.4600
# Epoch 35/10000
# 8/8 [==============================] - 2s 276ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.8467 - val_accuracy: 0.4600
# Epoch 36/10000
# 8/8 [==============================] - 3s 341ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.8700 - val_accuracy: 0.4600
# Epoch 37/10000
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.8686 - val_accuracy: 0.4600
# Epoch 38/10000
# 8/8 [==============================] - 2s 276ms/step - loss: 9.7801e-04 - accuracy: 1.0000 - val_loss: 3.8388 - val_accuracy: 0.4600
# Epoch 39/10000
# 8/8 [==============================] - 2s 273ms/step - loss: 8.3008e-04 - accuracy: 1.0000 - val_loss: 3.8828 - val_accuracy: 0.4600
# Epoch 40/10000
# 8/8 [==============================] - 2s 288ms/step - loss: 8.3059e-04 - accuracy: 1.0000 - val_loss: 3.9179 - val_accuracy: 0.4600
# Epoch 41/10000
# 8/8 [==============================] - 2s 280ms/step - loss: 7.4769e-04 - accuracy: 1.0000 - val_loss: 3.8943 - val_accuracy: 0.4600
# Epoch 42/10000
# 8/8 [==============================] - 3s 458ms/step - loss: 6.9252e-04 - accuracy: 1.0000 - val_loss: 3.9187 - val_accuracy: 0.4600
# Epoch 43/10000
# 8/8 [==============================] - 3s 371ms/step - loss: 6.4476e-04 - accuracy: 1.0000 - val_loss: 3.9207 - val_accuracy: 0.4600
# Epoch 44/10000
# 8/8 [==============================] - 2s 270ms/step - loss: 6.0220e-04 - accuracy: 1.0000 - val_loss: 3.9451 - val_accuracy: 0.4600
# Epoch 45/10000
# 8/8 [==============================] - 2s 288ms/step - loss: 5.7201e-04 - accuracy: 1.0000 - val_loss: 3.9662 - val_accuracy: 0.4600
# Epoch 46/10000
# 8/8 [==============================] - 2s 273ms/step - loss: 5.2985e-04 - accuracy: 1.0000 - val_loss: 3.9663 - val_accuracy: 0.4600
# Epoch 47/10000
# 8/8 [==============================] - 2s 288ms/step - loss: 4.9934e-04 - accuracy: 1.0000 - val_loss: 3.9649 - val_accuracy: 0.4600
# Epoch 48/10000
# 8/8 [==============================] - 4s 522ms/step - loss: 4.7989e-04 - accuracy: 1.0000 - val_loss: 3.9715 - val_accuracy: 0.4600
# Epoch 48: early stopping
# 8/8 [==============================] - 1s 60ms/step
# 2/2 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 44ms/step
#
# Evaluation of model on train data:
# 250/250 [==============================] - 1s 5ms/step - loss: 4.5889e-04 - accuracy: 1.0000
# ['loss', 'accuracy']
# [0.0004588868177961558, 1.0]
#
# Evaluation of model on validation data:
# 50/50 [==============================] - 0s 5ms/step - loss: 3.9715 - accuracy: 0.4600
# ['loss', 'accuracy']
# [3.9714531898498535, 0.46000000834465027]
#
# Evaluation of model on test data:
# 100/100 [==============================] - 0s 5ms/step - loss: 4.7137 - accuracy: 0.5700
# ['loss', 'accuracy']
# [4.71371603012085, 0.5699999928474426]
#
# Predictions for test data:
# 100/100 [==============================] - 0s 4ms/step
# [0 0 0 0 0 4 0 1 0 4 0 0 0 0 0 0 1 0 0 3 3 1 1 1 4 1 0 1 1 1 4 1 1 4 1 3 3
#  3 1 4 2 2 2 2 4 3 2 2 2 2 3 2 2 2 2 2 4 3 3 4 4 1 3 2 0 3 4 3 3 0 2 2 4 2
#  2 2 4 3 0 3 4 1 4 4 2 1 4 2 0 4 2 4 4 4 4 4 4 4 1 0]
# [[15  2  0  1  2]
#  [ 1 11  0  4  4]
#  [ 0  0 13  4  3]
#  [ 3  1  6  6  4]
#  [ 2  3  3  0 12]]

# %%
plt.imshow(trainInp[50])
#img=trainInp[0]
modelConv1 = Model(inputs=model.inputs, outputs=model.get_layer('conv1').output)
conv1FM = modelConv1.predict(trainInp)
print(conv1FM.shape)
plt.figure(figsize=(15,15))
for i in range(8):
    #displaying original image
    #clss=n
    #idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(4,4,i+1)
    plt.title('Feature Map-'+str(i))
    plt.imshow(conv1FM[50][ :, :, i])
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
#for i in range(8):
        #plt.imshow(conv1FM[0][ :, :, i])
plt.show()
# Out:
# 8/8 [==============================] - 0s 53ms/step
# (250, 54, 54, 8)

# %%
modelConv1 = Model(inputs=model.inputs, outputs=model.get_layer('conv2').output)
conv1FM = modelConv1.predict(trainInp)
print(conv1FM.shape)
plt.figure(figsize=(15,15))
for i in range(8):
    #displaying original image
    #clss=n
    #idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(4,4,i+1)
    plt.title('Feature Map-'+str(i))
    plt.imshow(conv1FM[50][ :, :, i])
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
#for i in range(8):
        #plt.imshow(conv1FM[0][ :, :, i])
plt.show()
# Out:
# 8/8 [==============================] - 1s 116ms/step
# (250, 22, 22, 16)

# %%
# Select the layer to visualize
last_conv_layer = model.get_layer('conv2')

# Define the gradient model
grad_model = keras.models.Model([model.inputs], [last_conv_layer.output, model.output])

# Load an image
img_path = '/content/drive/MyDrive/DLA5/Group_1/train/ewer/image_0004.jpg'
img = keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
preds = model.predict(img_array)
class_idx = np.argmax(preds[0])

# Generate the heatmap
with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(img_array)
    loss = predictions[:, class_idx]

grads = tape.gradient(loss, conv_outputs)[0]
guided_grads = (tf.cast(conv_outputs > 0, "float32") * tf.cast(grads > 0, "float32") * grads)

heatmap = tf.reduce_mean(guided_grads, axis=(0, 1))
# Add two dimensions to the heatmap tensor
heatmap = tf.expand_dims(tf.expand_dims(heatmap, 0), -1)
# Resize the heatmap to match the size of the input image
heatmap = tf.image.resize(heatmap, size=(img_array.shape[1], img_array.shape[2]))
# Remove the extra dimensions added above
heatmap = tf.squeeze(heatmap)
# Normalize the heatmap
heatmap = heatmap.numpy()
heatmap /= np.max(heatmap)

# Get the top activations
num_patches = 5 # Change this value to change the number of patches to visualize
patch_size = 32 # Change this value to change the size of the patches
top_activations = []
for i in range(num_patches):
    activation_value = np.max(heatmap)
    if activation_value == 0:
        break
    row, col = np.unravel_index(np.argmax(heatmap), heatmap.shape)
    top_activations.append((row, col, activation_value))
    heatmap[max(0, row-patch_size):min(img_array.shape[0], row+patch_size),
            max(0, col-patch_size):min(img_array.shape[1], col+patch_size)] = 0

# Overlay the patches on the input image
border_color = (255, 0, 225) # Change this value to change the color of the patch borders
border_thickness = 1 # Change this value to change the thickness of the patch borders
img_with_patches = img_array[0].copy()
for (row, col, activation_value) in top_activations:
    patch = img_array[0, max(0, row-patch_size):min(img_array.shape[0], row+patch_size),
                       max(0, col-patch_size):min(img_array.shape[1], col+patch_size)]
    cv2.rectangle(img_with_patches, (col-patch_size, row-patch_size),
                  (col+patch_size, row+patch_size), border_color, border_thickness)
    
# Display the input image with patches
plt.imshow(np.uint8( img_with_patches))
plt.show()
# Out:
# 1/1 [==============================] - 0s 168ms/step
