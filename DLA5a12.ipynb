# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os,sys
import cv2


import tensorflow as tf
from tensorflow import keras
from keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import pickle as p
from tensorflow.keras import layers, models
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix 
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array



initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=100)

def Upload_Dataset(Dataset_Path):
   
    Path_train_Dataset = Dataset_Path+"/train"
    Path_test_Dataset = Dataset_Path+"/test"
    Path_val_Dataset = Dataset_Path+"/val"
   
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = [], [], []
    Output_train, Output_test, Output_val = [], [], []

    for j in os.listdir(Path_train_Dataset):

        if j != ".DS_Store":
            #print(j)
            for k in os.listdir(Path_train_Dataset+"/"+j):
                img=cv2.imread(Path_train_Dataset+"/"+j+"/"+k)
                Input_train_Dataset.append(cv2.resize(img, (224, 224)))
                if(j == 'brain'):
                    print('0 Entered ',j)
                    Output_train.append(int(0))
                elif(j == 'ewer'):
                    print('1 Entered ',j)
                    Output_train.append(int(1))
                elif(j == 'helicopter'):
                    print('2 Entered ',j)
                    Output_train.append(int(2))
                elif(j == 'scorpion'):
                    print('3 Entered ',j)
                    Output_train.append(int(3))
                else:
                    print('4 Entered ',j)
                    Output_train.append(int(4))

            for k in os.listdir(Path_test_Dataset+"/"+j):
                img=cv2.imread(Path_test_Dataset+"/"+j+"/"+k)
                Input_test_Dataset.append(cv2.resize(img, (224, 224)))
                if(j == 'brain'):
                    Output_test.append(int(0))
                elif(j == 'ewer'):
                    Output_test.append(int(1))
                elif(j == 'helicopter'):
                    Output_test.append(int(2))
                elif(j == 'scorpion'):
                    Output_test.append(int(3))
                else:
                    Output_test.append(int(4))

            for k in os.listdir(Path_val_Dataset+"/"+j):
                img=cv2.imread(Path_val_Dataset+"/"+j+"/"+k)
                Input_val_Dataset.append(cv2.resize(img, (224, 224)))
                if(j == 'brain'):
                    Output_val.append(int(0))
                elif(j == 'ewer'):
                    Output_val.append(int(1))
                elif(j == 'helicopter'):
                    Output_val.append(int(2))
                elif(j == 'scorpion'):
                    Output_val.append(int(3))
                else:
                    Output_val.append(int(4))
       
    #print(Output_train)            
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = np.array(Input_train_Dataset), np.array(Input_test_Dataset), np.array(Input_val_Dataset)
    #Output_train, Output_test, Output_val = np.array(list(map(int, Output_train))), np.array(list(map(int, Output_test))), np.array(list(map(int, Output_val)))
    Output_train, Output_test, Output_val = np.array(Output_train), np.array(Output_test), np.array(Output_val)
    #print(Output_train)
    return Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val
#providing path of  Caltech-101 dataset
Dataset_Path = "/content/drive/MyDrive/DLA5/Group_1"

#calling Upload_Dataset function
trainInp, testInp,valInp, trainOut, testOut, valOut= Upload_Dataset(Dataset_Path)

#Architecture2
model = models.Sequential()
#First Layer
model.add(layers.Conv2D(8, (11, 11), strides=4,activation='relu',name='conv1', padding='valid',input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((3, 3,), strides=2,name='MaxPool1', padding='valid'))

#Second Layer
model.add(layers.Conv2D(16, (5, 5), strides=1,activation='relu',name='conv2',padding='valid', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((3, 3,), strides=2, name='MaxPool2',padding='valid'))
#3 Layer
model.add(layers.Conv2D(32, (3, 3), strides=1,activation='relu',name='conv3',padding='valid', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((3, 3,), strides=2, name='MaxPool3',padding='valid'))

#4th layer

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu', name='hiddenLayer'))
#5th layer
model.add(layers.Dense(5, activation='softmax', name='outputLayer'))

model.summary()

optimizer=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-6,name='Adam')

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=3,verbose=1)

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x = trainInp, y = trainOut, batch_size = 32, epochs = 10000, verbose = "auto", callbacks=[es], validation_data=(valInp,  valOut), validation_batch_size=1)

model.save('/content/drive/MyDrive/DLA5/a2.h5')
f=open('/content/drive/MyDrive/DLA5/Hist2.pckl','wb')
p.dump(history.history,f)
f.close()

'''Dataset used for prediction and evaluation  data'''
trainEncode=model.predict(trainInp)
valEncode=model.predict(valInp)
testEncode=model.predict(testInp)

#a,b-part

print('\nEvaluation of model on train data:')
trainAcc=model.evaluate(x=trainInp,y=trainOut,batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(trainAcc)

print('\nEvaluation of model on validation data:')
valAcc=model.evaluate(x=valInp, y=valOut, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(valAcc)

print('\nEvaluation of model on test data:')
testAcc=model.evaluate(x=testInp, y=testOut, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(testAcc)

print('\nPredictions for test data:')
testProb=model.predict(testInp, batch_size=1, verbose="auto", callbacks=None)
pred=np.argmax(testProb,axis=1)
print(pred)

'''3-3'''
#confusionMatrix=confusion_matrix(Output_test, pred)
confusionMatrix=confusion_matrix(testOut,pred)
#confusionMatrix=tf.math.confusion_matrix(Output_test, pred5)
print(confusionMatrix)
# Out:
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 0 Entered  brain
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 1 Entered  ewer
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 2 Entered  helicopter
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 3 Entered  scorpion
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# 4 Entered  starfish
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 54, 54, 8)         2912
#
#  MaxPool1 (MaxPooling2D)     (None, 26, 26, 8)         0
#
#  conv2 (Conv2D)              (None, 22, 22, 16)        3216
#
#  MaxPool2 (MaxPooling2D)     (None, 10, 10, 16)        0
#
#  conv3 (Conv2D)              (None, 8, 8, 32)          4640
#
#  MaxPool3 (MaxPooling2D)     (None, 3, 3, 32)          0
#
#  flatten (Flatten)           (None, 288)               0
#
#  hiddenLayer (Dense)         (None, 128)               36992
#
#  outputLayer (Dense)         (None, 5)                 645
#
# =================================================================
# Total params: 48,405
# Trainable params: 48,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# 8/8 [==============================] - 5s 413ms/step - loss: 10.1671 - accuracy: 0.2400 - val_loss: 2.5540 - val_accuracy: 0.2400
# Epoch 2/10000
# 8/8 [==============================] - 4s 568ms/step - loss: 2.1257 - accuracy: 0.3160 - val_loss: 1.5029 - val_accuracy: 0.3800
# Epoch 3/10000
# 8/8 [==============================] - 2s 306ms/step - loss: 1.6009 - accuracy: 0.4040 - val_loss: 1.4750 - val_accuracy: 0.4600
# Epoch 4/10000
# 8/8 [==============================] - 2s 295ms/step - loss: 1.2867 - accuracy: 0.4880 - val_loss: 1.3515 - val_accuracy: 0.4200
# Epoch 5/10000
# 8/8 [==============================] - 2s 285ms/step - loss: 1.2708 - accuracy: 0.4960 - val_loss: 1.3340 - val_accuracy: 0.4200
# Epoch 6/10000
# 8/8 [==============================] - 4s 522ms/step - loss: 1.1433 - accuracy: 0.5480 - val_loss: 1.5162 - val_accuracy: 0.3600
# Epoch 7/10000
# 8/8 [==============================] - 7s 784ms/step - loss: 1.2283 - accuracy: 0.5360 - val_loss: 1.2779 - val_accuracy: 0.5000
# Epoch 8/10000
# 8/8 [==============================] - 6s 698ms/step - loss: 0.9602 - accuracy: 0.6520 - val_loss: 1.2356 - val_accuracy: 0.5600
# Epoch 9/10000
# 8/8 [==============================] - 4s 547ms/step - loss: 0.8018 - accuracy: 0.7280 - val_loss: 1.2366 - val_accuracy: 0.6000
# Epoch 10/10000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.7473 - accuracy: 0.7040 - val_loss: 1.1018 - val_accuracy: 0.5800
# Epoch 11/10000
# 8/8 [==============================] - 3s 330ms/step - loss: 0.6484 - accuracy: 0.7600 - val_loss: 1.0284 - val_accuracy: 0.6400
# Epoch 12/10000
# 8/8 [==============================] - 3s 322ms/step - loss: 0.6445 - accuracy: 0.7960 - val_loss: 1.0931 - val_accuracy: 0.6000
# Epoch 13/10000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5115 - accuracy: 0.8440 - val_loss: 0.9784 - val_accuracy: 0.6800
# Epoch 14/10000
# 8/8 [==============================] - 4s 594ms/step - loss: 0.4200 - accuracy: 0.8520 - val_loss: 1.0406 - val_accuracy: 0.6000
# Epoch 15/10000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3886 - accuracy: 0.8880 - val_loss: 1.1495 - val_accuracy: 0.5200
# Epoch 16/10000
# 8/8 [==============================] - 3s 351ms/step - loss: 0.3240 - accuracy: 0.9320 - val_loss: 1.0069 - val_accuracy: 0.6600
# Epoch 17/10000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.2464 - accuracy: 0.9240 - val_loss: 0.9985 - val_accuracy: 0.7200
# Epoch 18/10000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.2318 - accuracy: 0.9440 - val_loss: 1.0602 - val_accuracy: 0.7000
# Epoch 19/10000
# 8/8 [==============================] - 5s 622ms/step - loss: 0.1893 - accuracy: 0.9400 - val_loss: 1.0242 - val_accuracy: 0.7200
# Epoch 20/10000
# 8/8 [==============================] - 3s 334ms/step - loss: 0.1465 - accuracy: 0.9840 - val_loss: 1.1170 - val_accuracy: 0.6600
# Epoch 21/10000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.1395 - accuracy: 0.9640 - val_loss: 1.0665 - val_accuracy: 0.6600
# Epoch 22/10000
# 8/8 [==============================] - 2s 289ms/step - loss: 0.0991 - accuracy: 0.9920 - val_loss: 1.0072 - val_accuracy: 0.7000
# Epoch 23/10000
# 8/8 [==============================] - 3s 411ms/step - loss: 0.0743 - accuracy: 0.9960 - val_loss: 1.3095 - val_accuracy: 0.5600
# Epoch 24/10000
# 8/8 [==============================] - 4s 472ms/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 1.1300 - val_accuracy: 0.6800
# Epoch 25/10000
# 8/8 [==============================] - 3s 328ms/step - loss: 0.0808 - accuracy: 0.9920 - val_loss: 1.4250 - val_accuracy: 0.6000
# Epoch 26/10000
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0800 - accuracy: 0.9880 - val_loss: 1.3227 - val_accuracy: 0.6800
# Epoch 27/10000
# 8/8 [==============================] - 3s 334ms/step - loss: 0.0726 - accuracy: 0.9880 - val_loss: 1.2953 - val_accuracy: 0.6400
# Epoch 27: early stopping
# 8/8 [==============================] - 1s 121ms/step
# 2/2 [==============================] - 0s 75ms/step
# 4/4 [==============================] - 0s 82ms/step
#
# Evaluation of model on train data:
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0358 - accuracy: 1.0000
# ['loss', 'accuracy']
# [0.03579295426607132, 1.0]
#
# Evaluation of model on validation data:
# 50/50 [==============================] - 0s 4ms/step - loss: 1.2953 - accuracy: 0.6400
# ['loss', 'accuracy']
# [1.2953332662582397, 0.6399999856948853]
#
# Evaluation of model on test data:
# 100/100 [==============================] - 0s 4ms/step - loss: 1.6959 - accuracy: 0.6300
# ['loss', 'accuracy']
# [1.6959388256072998, 0.6299999952316284]
#
# Predictions for test data:
# 100/100 [==============================] - 0s 4ms/step
# [0 0 0 0 0 4 4 0 1 0 0 0 0 1 0 4 0 1 0 4 1 1 0 1 1 1 1 1 4 1 3 3 1 1 3 1 1
#  2 1 1 3 2 2 2 4 1 4 0 2 3 2 2 2 4 2 2 2 2 2 2 3 0 4 4 1 3 3 2 1 2 2 1 3 3
#  3 4 4 3 0 3 3 2 3 4 4 4 4 2 4 4 4 4 4 4 4 4 4 4 4 3]
# [[13  3  0  0  4]
#  [ 1 14  1  3  1]
#  [ 1  1 13  2  3]
#  [ 2  3  3  8  4]
#  [ 0  0  2  3 15]]

# %%
plt.imshow(trainInp[50])
#img=trainInp[0]
modelConv1 = Model(inputs=model.inputs, outputs=model.get_layer('conv1').output)
conv1FM = modelConv1.predict(trainInp)
print(conv1FM.shape)
plt.figure(figsize=(15,15))
for i in range(8):
    #displaying original image
    #clss=n
    #idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(4,4,i+1)
    plt.title('Feature Map-'+str(i))
    plt.imshow(conv1FM[50][ :, :, i])
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
#for i in range(8):
        #plt.imshow(conv1FM[0][ :, :, i])
plt.show()
# Out:
# 8/8 [==============================] - 1s 60ms/step
# (250, 54, 54, 8)

# %%
modelConv1 = Model(inputs=model.inputs, outputs=model.get_layer('conv2').output)
conv1FM = modelConv1.predict(trainInp)
print(conv1FM.shape)
plt.figure(figsize=(15,15))
for i in range(8):
    #displaying original image
    #clss=n
    #idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(4,4,i+1)
    plt.title('Feature Map-'+str(i))
    plt.imshow(conv1FM[50][ :, :, i])
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
#for i in range(8):
        #plt.imshow(conv1FM[0][ :, :, i])
plt.show()
# Out:
# 8/8 [==============================] - 1s 113ms/step
# (250, 22, 22, 16)

# %%
modelConv1 = Model(inputs=model.inputs, outputs=model.get_layer('conv3').output)
conv1FM = modelConv1.predict(trainInp)
print(conv1FM.shape)
plt.figure(figsize=(15,15))
for i in range(8):
    #displaying original image
    #clss=n
    #idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(4,4,i+1)
    plt.title('Feature Map-'+str(i))
    plt.imshow(conv1FM[50][ :, :, i])
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
#for i in range(8):
        #plt.imshow(conv1FM[0][ :, :, i])
plt.show()
# Out:
# 8/8 [==============================] - 2s 187ms/step
# (250, 8, 8, 32)

# %%
# Select the layer to visualize
last_conv_layer = model.get_layer('conv3')

# Define the gradient model
grad_model = keras.models.Model([model.inputs], [last_conv_layer.output, model.output])

# Load an image
img_path = '/content/drive/MyDrive/DLA5/Group_1/train/ewer/image_0004.jpg'
img = keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
preds = model.predict(img_array)
class_idx = np.argmax(preds[0])

# Generate the heatmap
with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(img_array)
    loss = predictions[:, class_idx]

grads = tape.gradient(loss, conv_outputs)[0]
guided_grads = (tf.cast(conv_outputs > 0, "float32") * tf.cast(grads > 0, "float32") * grads)

heatmap = tf.reduce_mean(guided_grads, axis=(0, 1))
# Add two dimensions to the heatmap tensor
heatmap = tf.expand_dims(tf.expand_dims(heatmap, 0), -1)
# Resize the heatmap to match the size of the input image
heatmap = tf.image.resize(heatmap, size=(img_array.shape[1], img_array.shape[2]))
# Remove the extra dimensions added above
heatmap = tf.squeeze(heatmap)
# Normalize the heatmap
heatmap = heatmap.numpy()
heatmap /= np.max(heatmap)

# Get the top activations
num_patches = 5 # Change this value to change the number of patches to visualize
patch_size = 32 # Change this value to change the size of the patches
top_activations = []
for i in range(num_patches):
    activation_value = np.max(heatmap)
    if activation_value == 0:
        break
    row, col = np.unravel_index(np.argmax(heatmap), heatmap.shape)
    top_activations.append((row, col, activation_value))
    heatmap[max(0, row-patch_size):min(img_array.shape[0], row+patch_size),
            max(0, col-patch_size):min(img_array.shape[1], col+patch_size)] = 0

# Overlay the patches on the input image
border_color = (255, 0, 225) # Change this value to change the color of the patch borders
border_thickness = 1 # Change this value to change the thickness of the patch borders
img_with_patches = img_array[0].copy()
for (row, col, activation_value) in top_activations:
    patch = img_array[0, max(0, row-patch_size):min(img_array.shape[0], row+patch_size),
                       max(0, col-patch_size):min(img_array.shape[1], col+patch_size)]
    cv2.rectangle(img_with_patches, (col-patch_size, row-patch_size),
                  (col+patch_size, row+patch_size), border_color, border_thickness)
    
# Display the input image with patches
plt.imshow(np.uint8( img_with_patches))
plt.show()
# Out:
# 1/1 [==============================] - 0s 94ms/step
